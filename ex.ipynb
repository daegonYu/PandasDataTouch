# %%
import os
 
path_dir = './대안제시'
 
file_list = os.listdir(path_dir)
file_list
# Out:
# ['대안제시_고등_1학년_ESSAY_33793.json',
#  '대안제시_고등_1학년_ESSAY_33795.json',
#  '대안제시_고등_1학년_ESSAY_33806.json',
#  '대안제시_고등_1학년_ESSAY_33807.json',
#  '대안제시_고등_1학년_ESSAY_33808.json',
#  '대안제시_고등_1학년_ESSAY_33810.json',
#  '대안제시_고등_1학년_ESSAY_33811.json',
#  '대안제시_고등_1학년_ESSAY_33812.json',
#  '대안제시_고등_1학년_ESSAY_33813.json',
#  '대안제시_고등_1학년_ESSAY_33815.json',
#  '대안제시_고등_1학년_ESSAY_33816.json',
#  '대안제시_고등_1학년_ESSAY_33818.json',
#  '대안제시_고등_1학년_ESSAY_33819.json',
#  '대안제시_고등_1학년_ESSAY_33820.json',
#  '대안제시_고등_1학년_ESSAY_33821.json',
#  '대안제시_고등_1학년_ESSAY_33822.json',
#  '대안제시_고등_1학년_ESSAY_33823.json',
#  '대안제시_고등_1학년_ESSAY_33825.json',
#  '대안제시_고등_1학년_ESSAY_33826.json',
#  '대안제시_고등_1학년_ESSAY_33827.json',
#  '대안제시_고등_1학년_ESSAY_33828.json',
#  '대안제시_고등_1학년_ESSAY_33829.json',
#  '대안제시_고등_1학년_ESSAY_33832.json',
#  '대안제시_고등_1학년_ESSAY_33833.json',
#  '대안제시_고등_1학년_ESSAY_33834.json',
#  '대안제시_고등_1학년_ESSAY_33835.json',
#  '대안제시_고등_1학년_ESSAY_33836.json',
#  '대안제시_고등_1학년_ESSAY_33837.json',
# ...

# %%
import pandas as pd
import json


essay_df = pd.read_csv('대안제시.csv', index_col=0)

path = './대안제시/'

# for file in file_list:
import json
# file_path = './대안제시/대안제시_고등_1학년_ESSAY_33834.json'
file_path = path + file_list[0]
for i in range(1,len(file_list)):
    file_path = path + file_list[i]
    with open(file_path) as file:
        js = json.loads(file.read())
        df = pd.DataFrame(js,index=[0])
        essay_df = pd.concat([essay_df,df], axis=0)

# js
# df = pd.DataFrame(data['essay_txt'])
essay_df.to_csv("대안제시.csv")

# %%
import pandas as pd
essay_df = pd.read_csv('대안제시.csv')

# %%
essay_df = essay_df.drop(['Unnamed: 0', 'essay_id'], axis=1)
essay_df
# Out:
#                                               essay_txt
# 0     혐오시설을 설치하는것은 당연하게도 반발을 얻을 수 밖에 없다. #@문장구분#그이유로...
# 1     동물장묘시설을 건설함으로써 발생하는 여러 가지 문제들을 해결하기 위한 대안이 몇 가...
# 2     하수처리장을 설치하면 좋지않은 외관과 약취의 문제는 피할 수 없다.#@문장구분# 그...
# 3     만약, 당신의 집 옆에 쓰레기 매립지를 만든다고 하면 당신은 어떤 반응을 보일까요?...
# 4     이번 여름 전주의 한 마을에서 폐기물 매립지가 악취와 주변 지역의 쾌적성이 훼손된다...
# ...                                                 ...
# 5154  제 생각에는 반려동물도 사실은 인간과 동일한 생명입니다#@문장구분# 몇몇 도덕성이나...
# 5155  저의 주장을 얘기하면 이렇습니다.#@문장구분# 반려동물이 애견샵이나 동물판매점에서 ...
# 5156  반려동물 유기 문제를 해결하기 위해서는 주인들이 반려동물들을 키울 때 필요한 것들에...
# 5157  반려동물에 대한 이슈는 전부터 많이 있었다. 그러한 사례를 뉴스에서 쉽게 볼 수 있...
# 5158  우리 주변에는 반려동물을 키우는 사람들이 많습니다. #@문장구분#그정도로 반려동물을...
#
# [5159 rows x 1 columns]

# %%
essay_df.to_csv("대안제시.csv")

# %%
essay_df
# Out:
#                                               essay_txt
# 0     혐오시설을 설치하는것은 당연하게도 반발을 얻을 수 밖에 없다. #@문장구분#그이유로...
# 1     동물장묘시설을 건설함으로써 발생하는 여러 가지 문제들을 해결하기 위한 대안이 몇 가...
# 2     하수처리장을 설치하면 좋지않은 외관과 약취의 문제는 피할 수 없다.#@문장구분# 그...
# 3     만약, 당신의 집 옆에 쓰레기 매립지를 만든다고 하면 당신은 어떤 반응을 보일까요?...
# 4     이번 여름 전주의 한 마을에서 폐기물 매립지가 악취와 주변 지역의 쾌적성이 훼손된다...
# ...                                                 ...
# 5154  제 생각에는 반려동물도 사실은 인간과 동일한 생명입니다#@문장구분# 몇몇 도덕성이나...
# 5155  저의 주장을 얘기하면 이렇습니다.#@문장구분# 반려동물이 애견샵이나 동물판매점에서 ...
# 5156  반려동물 유기 문제를 해결하기 위해서는 주인들이 반려동물들을 키울 때 필요한 것들에...
# 5157  반려동물에 대한 이슈는 전부터 많이 있었다. 그러한 사례를 뉴스에서 쉽게 볼 수 있...
# 5158  우리 주변에는 반려동물을 키우는 사람들이 많습니다. #@문장구분#그정도로 반려동물을...
#
# [5159 rows x 1 columns]

# %%
import os
 
path_dir = './주장'
 
file_list = os.listdir(path_dir)
file_list
# Out:
# ['주장_고등_1학년_ESSAY_34013.json',
#  '주장_고등_1학년_ESSAY_34014.json',
#  '주장_고등_1학년_ESSAY_34015.json',
#  '주장_고등_1학년_ESSAY_34055.json',
#  '주장_고등_1학년_ESSAY_34056.json',
#  '주장_고등_1학년_ESSAY_34373.json',
#  '주장_고등_1학년_ESSAY_34374.json',
#  '주장_고등_1학년_ESSAY_34492.json',
#  '주장_고등_1학년_ESSAY_34863.json',
#  '주장_고등_1학년_ESSAY_35530.json',
#  '주장_고등_1학년_ESSAY_35532.json',
#  '주장_고등_1학년_ESSAY_35533.json',
#  '주장_고등_1학년_ESSAY_35534.json',
#  '주장_고등_1학년_ESSAY_35535.json',
#  '주장_고등_1학년_ESSAY_35536.json',
#  '주장_고등_1학년_ESSAY_35584.json',
#  '주장_고등_1학년_ESSAY_35585.json',
#  '주장_고등_1학년_ESSAY_35586.json',
#  '주장_고등_1학년_ESSAY_35588.json',
#  '주장_고등_1학년_ESSAY_35613.json',
#  '주장_고등_1학년_ESSAY_40869.json',
#  '주장_고등_1학년_ESSAY_43956.json',
#  '주장_고등_1학년_ESSAY_43957.json',
#  '주장_고등_1학년_ESSAY_43958.json',
#  '주장_고등_1학년_ESSAY_44224.json',
#  '주장_고등_1학년_ESSAY_44861.json',
#  '주장_고등_1학년_ESSAY_47280.json',
#  '주장_고등_1학년_ESSAY_47281.json',
#  '주장_고등_1학년_ESSAY_47282.json',
#  '주장_고등_1학년_ESSAY_47315.json',
# ...

# %%
import pandas as pd
import json


essay_df = pd.read_csv('주장.csv', index_col=0)

path = './주장/'


import json

# file_path = path + file_list[0]
# with open(file_path) as file:
#         js = json.loads(file.read())
#         df = pd.DataFrame(js,index=[0])
# df.to_csv("주장.csv")


for i in range(1,len(file_list)):
    file_path = path + file_list[i]
    with open(file_path) as file:
        js = json.loads(file.read())
        df = pd.DataFrame(js,index=[0])
        essay_df = pd.concat([essay_df,df], axis=0)

essay_df.to_csv("주장.csv")

# %%
essay_df
# Out:
#                                             essay_txt     essay_id
# 0   우리나라에서 수능과 고등학교 시절 입시 결과는 인생에서 가장 중요한 부분을 차지한다...  ESSAY_34013
# 0   우리는 무엇을 위해 공부하고 있을까?#@문장구분# 대부분의 학생이 대입, 입시라고 ...  ESSAY_34014
# 0   평가는 일반적으로 평가대상의 장점과 가치를 결정하는 과정을 말한다.#@문장구분# 그...  ESSAY_34015
# 0   수학능력시험, 줄여서 수능이라고 불리는 이 시험은 대한민국의 대학 입시에 필수 요소...  ESSAY_34055
# 0   단도직입적으로 말하자면 난 우리나라의 입시제도에 결함이 있다고 생각을 한다.#@문장...  ESSAY_34056
# ..                                                ...          ...
# 0   요즘 여러가지의 학교폭력이 자주 일어나고 있습니다.#@문장구분# 그로인해 여러가지 ...  ESSAY_80291
# 0   요즘 많은 아이들이 학교폭력을 겪고있습니다.#@문장구분# 학교폭력에는 많은 종류가 ...  ESSAY_80293
# 0   학교 폭력을 줄이기 위해 우리 같은 학생들이 할 수 있는 일은 생각보다 많습니다.#...  ESSAY_80294
# 0   요즈음 학교에서 학교폭력, 사이버 폭력을 당하는 학생이 늘어 사회적 문제가 되고 있...  ESSAY_80295
# 0   학교폭력, 어떻게 줄일까?#@문장구분#\n요즘, 학교에서 폭력이 점점늘어나고있다.#...  ESSAY_80296
#
# [8596 rows x 2 columns]

# %%
essay_df = essay_df.drop(['essay_id'], axis=1)
essay_df.to_csv("주장.csv")

# %%
essay_df = essay_df.reset_index()
essay_df
# Out:
#       index                                          essay_txt
# 0         0  우리나라에서 수능과 고등학교 시절 입시 결과는 인생에서 가장 중요한 부분을 차지한다...
# 1         0  우리는 무엇을 위해 공부하고 있을까?#@문장구분# 대부분의 학생이 대입, 입시라고 ...
# 2         0  평가는 일반적으로 평가대상의 장점과 가치를 결정하는 과정을 말한다.#@문장구분# 그...
# 3         0  수학능력시험, 줄여서 수능이라고 불리는 이 시험은 대한민국의 대학 입시에 필수 요소...
# 4         0  단도직입적으로 말하자면 난 우리나라의 입시제도에 결함이 있다고 생각을 한다.#@문장...
# ...     ...                                                ...
# 8591      0  요즘 여러가지의 학교폭력이 자주 일어나고 있습니다.#@문장구분# 그로인해 여러가지 ...
# 8592      0  요즘 많은 아이들이 학교폭력을 겪고있습니다.#@문장구분# 학교폭력에는 많은 종류가 ...
# 8593      0  학교 폭력을 줄이기 위해 우리 같은 학생들이 할 수 있는 일은 생각보다 많습니다.#...
# 8594      0  요즈음 학교에서 학교폭력, 사이버 폭력을 당하는 학생이 늘어 사회적 문제가 되고 있...
# 8595      0  학교폭력, 어떻게 줄일까?#@문장구분#\n요즘, 학교에서 폭력이 점점늘어나고있다.#...
#
# [8596 rows x 2 columns]

# %%
essay_df = essay_df.drop('index', axis=1)
essay_df
# Out:
#                                               essay_txt
# 0     우리나라에서 수능과 고등학교 시절 입시 결과는 인생에서 가장 중요한 부분을 차지한다...
# 1     우리는 무엇을 위해 공부하고 있을까?#@문장구분# 대부분의 학생이 대입, 입시라고 ...
# 2     평가는 일반적으로 평가대상의 장점과 가치를 결정하는 과정을 말한다.#@문장구분# 그...
# 3     수학능력시험, 줄여서 수능이라고 불리는 이 시험은 대한민국의 대학 입시에 필수 요소...
# 4     단도직입적으로 말하자면 난 우리나라의 입시제도에 결함이 있다고 생각을 한다.#@문장...
# ...                                                 ...
# 8591  요즘 여러가지의 학교폭력이 자주 일어나고 있습니다.#@문장구분# 그로인해 여러가지 ...
# 8592  요즘 많은 아이들이 학교폭력을 겪고있습니다.#@문장구분# 학교폭력에는 많은 종류가 ...
# 8593  학교 폭력을 줄이기 위해 우리 같은 학생들이 할 수 있는 일은 생각보다 많습니다.#...
# 8594  요즈음 학교에서 학교폭력, 사이버 폭력을 당하는 학생이 늘어 사회적 문제가 되고 있...
# 8595  학교폭력, 어떻게 줄일까?#@문장구분#\n요즘, 학교에서 폭력이 점점늘어나고있다.#...
#
# [8596 rows x 1 columns]

# %%
essay_df.to_csv("주장.csv")

# %%
df1 = pd.read_csv('대안제시.csv', index_col=0)
df2 = pd.read_csv('주장.csv', index_col=0)


essay_df = pd.concat([df1,df2], axis=0)
essay_df.to_csv("한글에세이.csv")

# %%
essay_df = essay_df.reset_index()
essay_df.to_csv("한글에세이.csv")

# %%
essay_df= essay_df.drop('index',axis=1)
essay_df.to_csv("한글에세이.csv")

# %%
essay_df
# Out:
#                                                essay_txt
# 0      혐오시설을 설치하는것은 당연하게도 반발을 얻을 수 밖에 없다. #@문장구분#그이유로...
# 1      동물장묘시설을 건설함으로써 발생하는 여러 가지 문제들을 해결하기 위한 대안이 몇 가...
# 2      하수처리장을 설치하면 좋지않은 외관과 약취의 문제는 피할 수 없다.#@문장구분# 그...
# 3      만약, 당신의 집 옆에 쓰레기 매립지를 만든다고 하면 당신은 어떤 반응을 보일까요?...
# 4      이번 여름 전주의 한 마을에서 폐기물 매립지가 악취와 주변 지역의 쾌적성이 훼손된다...
# ...                                                  ...
# 13750  요즘 여러가지의 학교폭력이 자주 일어나고 있습니다.#@문장구분# 그로인해 여러가지 ...
# 13751  요즘 많은 아이들이 학교폭력을 겪고있습니다.#@문장구분# 학교폭력에는 많은 종류가 ...
# 13752  학교 폭력을 줄이기 위해 우리 같은 학생들이 할 수 있는 일은 생각보다 많습니다.#...
# 13753  요즈음 학교에서 학교폭력, 사이버 폭력을 당하는 학생이 늘어 사회적 문제가 되고 있...
# 13754  학교폭력, 어떻게 줄일까?#@문장구분#\n요즘, 학교에서 폭력이 점점늘어나고있다.#...
#
# [13755 rows x 1 columns]
